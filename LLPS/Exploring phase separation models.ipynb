# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt


import time
import sys
import glob

import ipywidgets as widgets
from ipywidgets import Layout, interact, fixed

import io
from IPython.display import display

import pickle
import scipy
from scipy.optimize import leastsq

# %%
phi = np.arange(0,1,0.001)
s = -1 * ( phi*np.log(phi) + (1-phi)*np.log(1-phi))
# Out:
# C:\Users\RMCGORTY\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\RMCGORTY\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in multiply

# %%
plt.plot(phi, s, '-r.')
plt.ylabel("Entropy")
plt.xlabel("Volume Fraction")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# Text(0.5,0,'Volume Fraction')

# %%
phi = np.arange(0.001,1,0.001)
s = -1 * ( phi*np.log(phi) + (1-phi)*np.log(1-phi))
xi = 2.5
f = ( phi*np.log(phi) + (1-phi)*np.log(1-phi)) + (xi * phi * (1-phi))
fig = plt.figure()
plt.plot(phi, f, '-r.')
plt.xlabel("Volume Fraction")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# Text(0.5,0,'Volume Fraction')
