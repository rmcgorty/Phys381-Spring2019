# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
phi = np.arange(0,1,0.01)

# %%
S = (phi*np.log(phi))+((1-phi)*np.log(1-phi))
# Out:
# <ipython-input-20-cac8bf4a8211>:1: RuntimeWarning: divide by zero encountered in log
#   S = (phi*np.log(phi))+((1-phi)*np.log(1-phi))
# <ipython-input-20-cac8bf4a8211>:1: RuntimeWarning: invalid value encountered in multiply
#   S = (phi*np.log(phi))+((1-phi)*np.log(1-phi))

# %%
plt.figure()
plt.plot(phi, S, 'ro')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
xi=2.5
F = (phi*np.log(phi))+((1-phi)*np.log(1-phi)) + (xi*phi*(1-phi))

plt.figure()
plt.plot(phi, F, 'bo')
# Out:
# <ipython-input-22-ad45316cf877>:2: RuntimeWarning: divide by zero encountered in log
#   F = (phi*np.log(phi))+((1-phi)*np.log(1-phi)) + (xi*phi*(1-phi))
# <ipython-input-22-ad45316cf877>:2: RuntimeWarning: invalid value encountered in multiply
#   F = (phi*np.log(phi))+((1-phi)*np.log(1-phi)) + (xi*phi*(1-phi))
# <img src="data:image/png;base64,..." width="639.9999861283738">
