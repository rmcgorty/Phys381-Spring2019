# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

import pickle
import glob

# %% [markdown]
# This Jupyter Notebook file is meant to just introduce you to how the data is organized within pickled files.

# %%
#Just highlighting a possible use of the 'glob' function -- you may find this useful. 
# But you don't have to use it.
# Note that if you have a Mac, you might need to change the directory location below. 
fls = glob.glob(".\\SAMPLE DATA\\*Sine*.p")

# %%
#List the files found using the 'glob' function:
fls
# Out:
# ['.\\SAMPLE DATA\\Oscillations_Sine_113ma_0820_10Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_113ma_0820_12.5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_113ma_0820_15Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_113ma_0820_2.5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_113ma_0820_5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_113ma_0820_7.5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_95ma_0820_10Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_95ma_0820_12.5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_95ma_0820_15Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_95ma_0820_2.5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_95ma_0820_5Hz.p',
#  '.\\SAMPLE DATA\\Oscillations_Sine_95ma_0820_7.5Hz.p']

# %%
#Loading in a saved data set using the 'pickle' function
data_113_10 = pickle.load(open(fls[0],'rb'))

# %%
#Let's print out what is stored within this saved data set.
# Since this is a dictionary, we'll print out what the keys of it are.
print(data_113_10.keys())
# Out:
# dict_keys(['Fs', 'axis', 'dataOut', 'inputData_0', 'inputData_1', 'inputData_2', 'inputData_3'])

# %%
#The key 'Fs' is the frequency at which data was saved (e.g., sampling frequency). 
print("Looking at the data saved with the 'Fs' key, the sampling frequency was %i Hz." % data_113_10['Fs'])
# Out:
# Looking at the data saved with the 'Fs' key, the sampling frequency was 5000 Hz.

# %%
#The key 'axis' will tell us whether the stage oscillated along the x- or y-axis
print("The stage was oscillated along the %s as the bead was trapped." % data_113_10['axis'])
# Out:
# The stage was oscillated along the x-axis as the bead was trapped.

# %%
#We now deal with arrays of data that were saved.
print("The 'dataOut' array has a length of %i." % len(data_113_10['dataOut']))
# Out:
# The 'dataOut' array has a length of 5000.

# %%
#Define the time array. We can do this as we know the sampling frequency.
times = np.arange(0,len(data_113_10['dataOut']))*(1./data_113_10['Fs'])

# %%
fig = plt.figure()
plt.plot(times, data_113_10['dataOut'], label='Output to stage')
plt.plot(times, data_113_10['inputData_0'], label='Channel 0')
plt.plot(times, data_113_10['inputData_1'], label='Channel 1')
plt.plot(times, data_113_10['inputData_2'], label='Channel 2')
plt.plot(times, data_113_10['inputData_3'], label='Channel 3')
plt.legend(loc=2)
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Voltage (V)')

# %%
fig = plt.figure()
plt.plot(times, data_113_10['inputData_0']-data_113_10['inputData_0'].mean(), label='Channel 0')
plt.plot(times, data_113_10['inputData_2']-data_113_10['inputData_2'].mean(), label='Channel 2')
plt.legend(loc=2)
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Text(0, 0.5, 'Voltage (V)')
